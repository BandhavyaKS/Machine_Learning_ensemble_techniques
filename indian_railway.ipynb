# %%
from xgboost import XGBRegressor, XGBClassifier
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("indian_railway_failure_detection_maintenance_v2.csv")
df
# Out:
#        train_id                 region   season train_type  train_age_years  \
# 0             1       Northern Railway  Monsoon  Passenger               25
# 1             2        Western Railway   Summer  Passenger                4
# 2             3  South Central Railway   Summer      Metro               29
# 3             4        Eastern Railway   Summer    Freight               19
# 4             5       Northern Railway   Summer    Freight               31
# ...         ...                    ...      ...        ...              ...
# 99995     99996        Central Railway   Winter  Passenger               21
# 99996     99997        Eastern Railway   Summer    Express                6
# 99997     99998       Northern Railway  Monsoon    Freight               33
# 99998     99999       Southern Railway   Summer  Passenger                4
# 99999    100000       Southern Railway  Monsoon  Passenger               17
#
#        average_speed_kmph  distance_travelled_km  ambient_temperature_c  \
# 0               68.378675                 128246                   23.6
# 1               71.893467                  60105                   29.5
# 2               71.066133                  36621                   32.2
# 3               50.082049                  33287                   37.8
# 4               44.387655                  11723                   38.4
# ...                   ...                    ...                    ...
# 99995           79.636653                 191629                   22.9
# 99996          109.896064                 146086                   42.2
# 99997           43.609906                  88381                   30.0
# 99998           77.122216                  62278                   32.7
# 99999           70.182335                  49403                   24.3
#
#        humidity_percent  rainfall_mm  ...  brake_pressure_psi  \
# 0                  57.8         50.3  ...                89.0
# 1                  56.0          7.1  ...                91.8
# 2                  43.3          4.5  ...                86.2
# 3                  47.0          5.4  ...                97.5
# 4                  61.0          1.2  ...                89.0
# ...                 ...          ...  ...                 ...
# 99995              69.4          0.0  ...                92.5
# 99996              68.9          0.9  ...               106.6
# 99997               NaN        105.6  ...                73.0
# 99998              53.5          9.4  ...               116.6
# 99999              77.3         68.9  ...               101.3
#
#        battery_voltage  last_maintenance_days  sensor_health_index  \
# 0                22.80                     16                 94.8
# 1                25.22                    271                 36.5
# 2                21.84                     12                100.0
# 3                24.91                     67                 98.8
# 4                23.68                    235                 37.4
# ...                ...                    ...                  ...
# 99995            27.14                    118                 61.2
# 99996            26.56                    325                 39.7
# 99997            23.00                    255                 57.3
# 99998            26.43                    351                 39.2
# 99999            22.54                    181                 62.7
#
#        inspection_score  delay_minutes     failure_type  maintenance_required  \
# 0                  96.3          32.00              NaN                     0
# 1                  52.8           6.70  Bearing Failure                     1
# 2                  95.8           5.58     Track Defect                     1
# 3                  89.5           0.70  Bearing Failure                     1
# 4                  44.9           4.20              NaN                     0
# ...                 ...            ...              ...                   ...
# 99995              68.9           6.20              NaN                     0
# 99996              42.2           4.90              NaN                     0
# 99997              54.9          21.40     Track Defect                     1
# 99998              45.2           9.50              NaN                     0
# 99999              62.9          30.20              NaN                     0
#
#        failure_severity  risk_score
# 0                   NaN        58.9
# 1                Medium        75.3
# 2                   Low        62.5
# 3                   Low        50.0
# 4                   NaN        97.1
# ...                 ...         ...
# 99995               NaN        76.2
# 99996               NaN        71.2
# 99997              High        90.4
# 99998               NaN        81.1
# 99999               NaN        62.5
#
# [100000 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   train_id                100000 non-null  int64
#  1   region                  100000 non-null  object
#  2   season                  100000 non-null  object
#  3   train_type              100000 non-null  object
#  4   train_age_years         100000 non-null  int64
#  5   average_speed_kmph      100000 non-null  float64
#  6   distance_travelled_km   100000 non-null  int64
#  7   ambient_temperature_c   100000 non-null  float64
#  8   humidity_percent        95000 non-null   float64
#  9   rainfall_mm             92000 non-null   float64
#  10  wheel_wear_percent      97000 non-null   float64
#  11  track_vibration_level   94000 non-null   float64
#  12  rail_wear_mm            100000 non-null  float64
#  13  bearing_temperature_c   93000 non-null   float64
#  14  axle_temperature_c      100000 non-null  float64
#  15  brake_pad_wear_percent  100000 non-null  float64
#  16  brake_pressure_psi      100000 non-null  float64
#  17  battery_voltage         96000 non-null   float64
#  18  last_maintenance_days   100000 non-null  int64
#  19  sensor_health_index     100000 non-null  float64
#  20  inspection_score        100000 non-null  float64
#  21  delay_minutes           100000 non-null  float64
#  22  failure_type            30783 non-null   object
#  23  maintenance_required    100000 non-null  int64
#  24  failure_severity        30783 non-null   object
#  25  risk_score              100000 non-null  float64
# dtypes: float64(16), int64(5), object(5)
# memory usage: 19.8+ MB

# %%
XGBRegressor
